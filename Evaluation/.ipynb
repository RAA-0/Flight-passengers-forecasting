# %%
import pandas as pd

# %%
df_arrivals = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\New folder (2)\\FLIGHT_LOAD_ML_202310161702_arrival.csv", parse_dates=['SIBT'])

corona_set = df_arrivals[(df_arrivals['SIBT'].dt.year.isin([2021])) & (df_arrivals['SIBT'].dt.month.isin([7,4,9,11]) )]
corona_set=corona_set.dropna()

#sample = corona_set.sample(100)
sample =corona_set

# %%
sample
# Out:
#                          FLIGHTID FLIGHTNUMBER AD_FLAG                SIBT  \
# 72975   732185401AODB-UFISA-final       AF 662       A 2020-07-15 18:25:00
# 72976   732185497AODB-UFISA-final       AF 662       A 2020-07-22 18:25:00
# 72977   732185641AODB-UFISA-final       AF 662       A 2020-08-01 18:35:00
# 72978   732185689AODB-UFISA-final       AF 662       A 2020-08-05 18:35:00
# 72982   732188907AODB-UFISA-final       AF 662       A 2020-09-26 18:35:00
# ...                           ...          ...     ...                 ...
# 388810  912136472AODB-UFISA-final      FZ 8780       A 2020-12-16 12:40:00
# 389115  928067240AODB-UFISA-final      FZ 8004       A 2020-12-30 11:00:00
# 389116  928067241AODB-UFISA-final      FZ 8004       A 2020-12-31 11:00:00
# 389120  928067902AODB-UFISA-final      FZ 8296       A 2020-12-31 14:15:00
# 389313  939007754AODB-UFISA-final      FZ 4628       A 2020-12-29 15:30:00
#
#                            EIBT                     AIBT  \
# ...

# %%
sample.to_csv("corona_cases.csv",index=False)
