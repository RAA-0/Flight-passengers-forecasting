# %%
import pandas as pd

# %%
#hajj - summer season 
df = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\New folder (2)\\arrival_dataset.csv")

df['SIBT']= pd.to_datetime(df['SIBT'])
df = df[df['SIBT'].dt.year==2023]
df = df[df['SIBT'].dt.month.isin([2,3,5])]
df = df[df['SIBT'].dt.day.isin([26,27,28])]

df
# Out:
#                           FLIGHTID FLIGHTNUMBER AD_FLAG                SIBT  \
# 11574   2210004114AODB-UFISA-final      3U 3917       A 2023-02-27 21:45:00
# 11605   2210009332AODB-UFISA-final       6H 661       A 2023-02-26 08:55:00
# 11627   2210009700AODB-UFISA-final       6H 665       A 2023-02-26 15:15:00
# 11667   2210010671AODB-UFISA-final       AC 056       A 2023-02-26 15:35:00
# 11807   2210012281AODB-UFISA-final       AI 911       A 2023-02-26 22:40:00
# ...                            ...          ...     ...                 ...
# 365098  2305035576AODB-UFISA-final       FZ 662       A 2023-07-28 08:30:00
# 365107  2305036362AODB-UFISA-final       FZ 172       A 2023-07-28 19:30:00
# 365129  2306223276AODB-UFISA-final       FZ 910       A 2023-07-26 12:25:00
# 365139  2306248640AODB-UFISA-final       FZ 648       A 2023-07-27 16:35:00
# 365153  2307036793AODB-UFISA-final      FZ 8178       A 2023-07-27 21:55:00
#
# ...

# %%
#diwali 

df = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\New folder (2)\\arrival_dataset.csv")

df['SIBT']= pd.to_datetime(df['SIBT'])

df = df[df['SIBT'].dt.year==2022]
df = df[df['SIBT'].dt.month.isin([11])]
df = df[df['SIBT'].dt.day>=24]

df
# Out:
#                           FLIGHTID FLIGHTNUMBER AD_FLAG                SIBT  \
# 11583   2210009206AODB-UFISA-final       6H 661       A 2022-11-29 08:45:00
# 11634   2210009758AODB-UFISA-final       6H 665       A 2022-11-30 11:55:00
# 11656   2210010542AODB-UFISA-final       AC 056       A 2022-11-28 15:35:00
# 11657   2210010544AODB-UFISA-final       AC 056       A 2022-11-29 15:35:00
# 11712   2210011061AODB-UFISA-final       AF 662       A 2022-11-25 19:20:00
# ...                            ...          ...     ...                 ...
# 357620  2210229913AODB-UFISA-final       FZ 372       A 2022-11-27 14:25:00
# 357658  2210252110AODB-UFISA-final       FZ 976       A 2022-11-29 05:05:00
# 357692  2211015316AODB-UFISA-final       FZ 502       A 2022-11-26 08:50:00
# 357703  2211032701AODB-UFISA-final       FZ 716       A 2022-11-30 13:45:00
# 357717  2211047402AODB-UFISA-final       EK 726       A 2022-11-28 01:25:00
#
# ...

# %%
df.to_csv("eval_set.csv",index=False)
